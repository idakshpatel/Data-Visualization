# %%
'''1. Using the given dataset, to generate a 3D scatter plot to visualize the distribution of data points in a three-
dimensional space.
np. random. seed (30)
data -
np. random . uniform (-19,
np. random . uniform( -10,
'Y':
np. random. -IO,
df = pd.DataFrame(data)
10,
13,
10,
390) ,
390) ,
300)'''



import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# 1. 3D Scatter Plot
np.random.seed(30)
data_3d = {
    'X': np.random.uniform(-10, 10, 300),
    'Y': np.random.uniform(-10, 10, 300),
    'Z': np.random.uniform(-10, 10, 300)
}
df_3d = pd.DataFrame(data_3d)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_3d['X'], df_3d['Y'], df_3d['Z'], color='red', marker='o', alpha=0.7)
ax.set_title('3D Scatter Plot')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.show()

# %%
'''
2. using the Student Grades, create a violin plot to display the distribution Of scores across different grade
df =
categories.
np. random. seed(15)
data {
'Grade':
np. random. randint(50,
' Score':
df = pd.DataFrame(data)
200) ,
100, 200)
1. Using the sales data, generate a heatmap to visualize the variation in sates across
different months and days.
np. random. seed (20)
data -
'Month':
'Day':
np.random.randint(1@O@,
Sates':
pd. DataFrame (data)
'Feb', 'Mar',
31), 100),
5000, 100)
'Apr',
'May'], 180),'''





# 2. Violin Plot for Student Grades
np.random.seed(15)
data_grades = {
    'Grade': np.random.choice(['A', 'B', 'C', 'D', 'F'], 200),
    'Score': np.random.randint(50, 100, 200)
}
df_grades = pd.DataFrame(data_grades)

plt.figure(figsize=(10, 7))
sns.violinplot(x='Grade', y='Score', data=df_grades, palette='Set2')
plt.title('Violin Plot of Scores Across Grade Categories')
plt.xlabel('Grade')
plt.ylabel('Score')
plt.show()
# Out:
# C:\Users\Daksh Patel\AppData\Local\Temp\ipykernel_24644\1026838240.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Grade', y='Score', data=df_grades, palette='Set2')

# %%
'''
3. using the sales data, generate a heatmap to visualize the variation in sales across different months and
days.
np. random. seed (20)
data {
Feb', Mar
31), 100),
5000, 100)
'May'), 100),
df
np.random.choice(['Jan ,
'Nonth
np. random.
'Day':
pd.DataFrame(data)

'''




# 3. Heatmap for Sales Data
np.random.seed(20)
data_sales = {
    'Month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100),
    'Day': np.random.choice(range(1, 31), 100),
    'Sales': np.random.randint(1000, 5000, 100)
}
df_sales = pd.DataFrame(data_sales)

# Pivot the data to create a matrix for the heatmap
sales_pivot = df_sales.pivot_table(values='Sales', index='Day', columns='Month', aggfunc='mean')

plt.figure(figsize=(12, 8))
sns.heatmap(sales_pivot, annot=True, cmap='coolwarm', fmt='.0f', linewidths=0.5)
plt.title('Heatmap of Sales Data (Monthly and Daily)')
plt.xlabel('Month')
plt.ylabel('Day')
plt.show()

# %%
'''
4. Using the given x and y data, generate a 3D surface plot to visualize the function
Unspace(-5, 5, 100)
Y = np.Iinspace(-5, 5, 100)
x, y np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 +
data {
x. flatten()
'X':
y. flatten() ,
z flatten()
pd. DataFrame(data)
df

'''


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 1. Generate the x and y data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# 2. Define the function for the surface plot (e.g., Z = X^2 + Y^2)
Z = np.sin(np.sqrt(X**2 + Y**2))  # Example of a 3D function

# 3. Flatten the arrays to create a DataFrame
data = {
    'x': X.flatten(),
    'y': Y.flatten(),
    'z': Z.flatten()
}
df = pd.DataFrame(data)

# 4. Plot the 3D surface
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.8)

# Set plot title and labels
ax.set_title('3D Surface Plot')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

# Show the plot
plt.show()

# %%
'''5. using the given dataset, create a bubble chart to represent each country's population (y—axis), GDP (x—
axis), and bubble size proportional to the population.
np. random. seed (25)
data {
['USA ,
'Country':
' 'Canada', 'UK
France'],
'Germany' ,
' Population' :
np.random.randint(lße, 1088, 5),
df =
5)
np.random. randint(5€O,
'GDP':
pd . DataFrame (data)'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate the dataset
np.random.seed(25)
data = {
    'Country': ['USA', 'Canada', 'UK', 'Germany', 'France'],
    'Population': np.random.randint(10**7, 10**8, 5),  # Population in the range of 10 million to 100 million
    'GDP': np.random.randint(50000, 100000, 5)  # GDP in the range of 50,000 to 100,000 (for demonstration)
}

df = pd.DataFrame(data)

# Create the bubble chart
plt.figure(figsize=(10, 7))

# The bubble size is determined by 'Population', scaled for better visualization
bubble_size = df['Population'] / 10**6  # Scale down the population for bubble size

plt.scatter(df['GDP'], df['Population'], s=bubble_size, alpha=0.6, color='blue', edgecolors='w', linewidth=2)

# Annotate each country
for i in range(len(df)):
    plt.text(df['GDP'][i], df['Population'][i], df['Country'][i], fontsize=12, ha='center', va='center', color='black')

# Set titles and labels
plt.title('Bubble Chart: Population vs. GDP', fontsize=16)
plt.xlabel('GDP (in USD)', fontsize=14)
plt.ylabel('Population (in billions)', fontsize=14)
plt.grid(True)

# Display the plot
plt.show()
